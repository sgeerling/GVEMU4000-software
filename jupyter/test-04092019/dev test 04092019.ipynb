# %%
with open('apikey.txt') as f:
    api_key = f.readline()
    f.close
api_key= api_key[0:-1]
api_key
# Out:
# 'AIzaSyAy49fbMHQyLOxeJZ40tNDtR8uKqe5curg'

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key=api_key)

# %%
from sqlalchemy import create_engine                                                                                                                                    
                                                                                                                                                       
                                                                                                                                                                        
class Database:                                                                                                                                                         
    def __init__(self,                                                                                                                                                  
                 db_name="test_gopimn",                                                                                                                       
                 username="sa",                                                                                                                
                 pw="eTrans2019",                                                                                                                            
                 host="localhost",                                                                                                                        
                 port=1433):                                                                                                                  
                                                                                                                                                                        
        self.engine = create_engine('mssql+pymssql://{}:{}@{}:{}/{}'.format(username, pw, host, port, db_name))                                                         
                                                                                                                                                                        
                                                                                                                                     
db = Database()

# %%
from sqlalchemy import MetaData
from sqlalchemy import Table
from sqlalchemy import Column
from sqlalchemy import Integer
from sqlalchemy import String
from sqlalchemy import DateTime
from sqlalchemy import Float

truck_geo=[]
raw_all = []
t_stamp=[]
try:
    #sql_query = "select top 100 * from test_queue_raw where raw_data like '%+RESP:GTFRI,270601,865067022303617%' and Id >= 73515"
    sql_query = "select * from test_queue_raw where raw_data like '%+RESP:GTFRI,270601,865067022303617%' and Id >= 73515"
    cn = db.engine.connect()
    result = cn.execute(sql_query).fetchall()
    for row in result:  
        raw = row[1]
        frame = raw.split(",")
        raw_all += raw
        try:
            if frame[12]!='nan'  and frame[11]!='nan':
                curr_geo = [float(frame[12]) , float(frame[11])]
                truck_geo += [curr_geo]
                t_stamp.append(frame[13])
        except:
            print("bad ")
    cn.close()
except Exception as e:
    cn.close()
    raise e

# %%
len(truck_geo)
t_stamp[0]
gtfri_info= []
for i in range(0,len(truck_geo)):
    gtfri_info.append({'datetime':t_stamp[i], 'location':truck_geo[i]})

# %%
info_box_template = """
<dl>
<dt>time stamp</dt><dd>{datetime}</dd>
</dl>
"""
datetime_info = [info_box_template.format(**datetime) for datetime in gtfri_info]
datetime_info
# Out:
# ['\n<dl>\n<dt>time stamp</dt><dd>20190904142437</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142439</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142441</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142443</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142445</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142447</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142449</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142451</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142453</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142455</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142457</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142459</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142501</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142503</dd>\n</dl>\n',
#  '\n<dl>\n<dt>time stamp</dt><dd>20190904142505</dd>\n</dl>\n',
# ...

# %%
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(truck_geo, info_box_content=datetime_info)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
geos = []
with open('./draft','r') as file:
    lines = file.readlines()
    for line in lines:
        trama = line.split(",")
        if (trama[14] != 'nan'):
            curr =  [float(trama[15]),float(trama[14])]
            geos += [curr]
geos
# Out:
# [[-33.50066083, -70.614001063],
#  [-33.500660192, -70.614001719],
#  [-33.500659671, -70.614002685],
#  [-33.500660556, -70.614003614],
#  [-33.50066285, -70.614004387],
#  [-33.500665537, -70.614005547],
#  [-33.500668755, -70.614006815],
#  [-33.500674067, -70.614007464],
#  [-33.500679142, -70.61400812],
#  [-33.500687934, -70.614007092],
#  [-33.50069454, -70.614005838],
#  [-33.500695933, -70.614003407],
#  [-33.500696055, -70.614002055],
#  [-33.500695467, -70.614000959],
#  [-33.500695806, -70.613999559],
#  [-33.501751239, -70.614128509],
#  [-33.501739559, -70.614078231],
#  [-33.501732511, -70.614049247],
#  [-33.501730805, -70.614029043],
#  [-33.501729914, -70.614016091],
#  [-33.501731528, -70.614010426],
#  [-33.50173183, -70.614005467],
#  [-33.501734002, -70.613997604],
#  [-33.501740704, -70.613993493],
#  [-33.501742109, -70.613990489],
#  [-33.501745244, -70.613990282],
#  [-33.501754775, -70.613990414],
#  [-33.501760875, -70.613991151],
# ...

# %%
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(geos)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
